# %%
from hcve_lib.utils import notebook_init

notebook_init()

import json
from typing import Dict

import yaml
from mlflow import set_tracking_uri, get_run, search_runs

chosen_runs = {
    'lco':
        {'gb': 'dcd4db41ea934f37a0626ed19762bf7d', 'coxnet': 'f37cdf94668b4340b9e6512e1dfe7a56'}
}

from deps.hyperparameters import HYPERPARAMETERS_FILE

set_tracking_uri('http://localhost:5000')

def get_hyperparameters(run_id: str) -> Dict[str, Dict]:
    root_run = get_run(run_id)
    children_runs = search_runs(
        root_run.info.experiment_id,
        f'tags.mlflow.parentRunId = "{root_run.info.run_id}"',
        output_format='pandas')
    return {
        rows['tags.mlflow.runName']: json.loads(rows['params.hyperparameters'].replace("\'", "\""))
        for _, rows in children_runs.iterrows()
    }


hyperparameters = {
    experiment_name: {
        method_name: get_hyperparameters(run_id)
        for method_name, run_id in methods.items()
    }
    for experiment_name, methods in chosen_runs.items()
}

print(yaml.dump(hyperparameters))

with open(HYPERPARAMETERS_FILE, 'w') as f:
    json.dump(hyperparameters, f)
# Out:
# lco:
#   coxnet:
#     ASCOT:
#       estimator__inner:
#         alphas:
#         - 0.5874297044862964
#         l1_ratio: 0.00575174141945245
#     FLEMENGHO:
#       estimator__inner:
#         alphas:
#         - 0.6965683563912647
#         l1_ratio: 0.20562592215297149
#     HEALTHABC:
#       estimator__inner:
#         alphas:
#         - 0.7241804583576157
#         l1_ratio: 0.0008459384094903211
#     HVC:
#       estimator__inner:
#         alphas:
#         - 0.6154208894366343
#         l1_ratio: 0.31184850394190633
#     PREDICTOR:
#       estimator__inner:
#         alphas:
#         - 0.5096563050964983
#         l1_ratio: 0.0009829553330933383
#     PROSPER:
#       estimator__inner:
#         alphas:
#         - 0.8239104031859371
#         l1_ratio: 0.20680270201087592
#   gb:
#     ASCOT:
#       estimator__inner:
#         learning_rate: 0.42720126728965413
#         max_depth: 10
#         max_features: log2
#         min_samples_leaf: 186
#         min_samples_split: 4
#         n_estimators: 129
#         subsample: 0.3464104097831221
#     FLEMENGHO:
#       estimator__inner:
#         learning_rate: 0.5466796529740378
#         max_depth: 7
#         max_features: sqrt
#         min_samples_leaf: 96
#         min_samples_split: 26
#         n_estimators: 185
#         subsample: 0.9991143175593463
#     HEALTHABC:
#       estimator__inner:
#         learning_rate: 0.869134661511128
#         max_depth: 3
#         max_features: sqrt
#         min_samples_leaf: 192
#         min_samples_split: 10
#         n_estimators: 194
#         subsample: 0.8228469462266893
#     HVC:
#       estimator__inner:
#         learning_rate: 0.9892210928154446
#         max_depth: 7
#         max_features: log2
#         min_samples_leaf: 103
#         min_samples_split: 3
#         n_estimators: 49
#         subsample: 0.13427386116113538
#     PREDICTOR:
#       estimator__inner:
#         learning_rate: 0.6707117303939213
#         max_depth: 7
#         max_features: log2
#         min_samples_leaf: 131
#         min_samples_split: 14
#         n_estimators: 155
#         subsample: 0.3933553421418345
#     PROSPER:
#       estimator__inner:
#         learning_rate: 0.30944525538959256
#         max_depth: 8
#         max_features: auto
#         min_samples_leaf: 85
#         min_samples_split: 17
#         n_estimators: 135
#         subsample: 0.8562561477434878
